# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings

# %%
df=pd.read_csv("houseprice.csv")

# %%
df.head()
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        2       BHK  1300.236407
# 1    Dealer                   0     0        2       BHK  1275.000000
# 2     Owner                   0     0        2       BHK   933.159722
# 3     Owner                   0     1        2       BHK   929.921143
# 4    Dealer                   1     0        2       BHK   999.009247
#
#    READY_TO_MOVE  RESALE                      ADDRESS  LONGITUDE   LATITUDE  \
# 0              1       1        Ksfc Layout,Bangalore  12.969910  77.597960
# 1              1       1    Vishweshwara Nagar,Mysore  12.274538  76.644605
# 2              1       1             Jigani,Bangalore  12.778033  77.632191
# 3              1       1  Sector-1 Vaishali,Ghaziabad  28.642300  77.344500
# 4              0       1             New Town,Kolkata  22.592200  88.484911
#
#    TARGET(PRICE_IN_LACS)
# 0                   55.0
# 1                   51.0
# ...

# %%
df.shape
# Out:
# (29451, 12)

# %%
df.dtypes
# Out:
# POSTED_BY                 object
# UNDER_CONSTRUCTION         int64
# RERA                       int64
# BHK_NO.                    int64
# BHK_OR_RK                 object
# SQUARE_FT                float64
# READY_TO_MOVE              int64
# RESALE                     int64
# ADDRESS                   object
# LONGITUDE                float64
# LATITUDE                 float64
# TARGET(PRICE_IN_LACS)    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# POSTED_BY                0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# ADDRESS                  0
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['POSTED_BY', 'UNDER_CONSTRUCTION', 'RERA', 'BHK_NO.', 'BHK_OR_RK',
#        'SQUARE_FT', 'READY_TO_MOVE', 'RESALE', 'ADDRESS', 'LONGITUDE',
#        'LATITUDE', 'TARGET(PRICE_IN_LACS)'],
#       dtype='object')

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29446    False
# 29447    False
# 29448    False
# 29449    False
# 29450    False
# Length: 29451, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 401

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
fig,axis=plt.subplots(1,2,figsize=(16,6))
plt.subplot(121)
sns.histplot(data=df,x='TARGET(PRICE_IN_LACS)',bins=30,kde=True,hue='BHK_NO.')
# Out:
# <Axes: xlabel='TARGET(PRICE_IN_LACS)', ylabel='Count'>

# %%
plt.style.use('seaborn')
df.hist(bins=50,figsize=(20,15))
plt.show()
# Out:
# <ipython-input-13-5edbdf4a554a>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-14-8df7bcac526d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <ipython-input-15-f0f86bb9996e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# <ipython-input-15-f0f86bb9996e>:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_45df1_row0_col0, #T_45df1_row1_col1, #T_45df1_row2_col2, #T_45df1_row3_col3, #T_45df1_row4_col4, #T_45df1_row5_col5, #T_45df1_row6_col6, #T_45df1_row7_col7, #T_45df1_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_45df1_row0_col1 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_45df1_row0_col2, #T_45df1_row0_col4, #T_45df1_row0_col5, #T_45df1_row4_col0, #T_45df1_row4_col1, #T_45df1_row5_col8, #T_45df1_row6_col3, #T_45df1_row6_col7, #T_45df1_row7_col6 {
# ...

# %%
df['POSTED_BY'].unique()
# Out:
# array(['Owner', 'Dealer', 'Builder'], dtype=object)

# %%
to_numeric={'Owner':0, 'Dealer':1, 'Builder':2}
df.replace(to_numeric,inplace=True)

# %%
df.head()
# Out:
#    POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0          0                   0     0        2       BHK  1300.236407
# 1          1                   0     0        2       BHK  1275.000000
# 2          0                   0     0        2       BHK   933.159722
# 3          0                   0     1        2       BHK   929.921143
# 4          1                   1     0        2       BHK   999.009247
#
#    READY_TO_MOVE  RESALE                      ADDRESS  LONGITUDE   LATITUDE  \
# 0              1       1        Ksfc Layout,Bangalore  12.969910  77.597960
# 1              1       1    Vishweshwara Nagar,Mysore  12.274538  76.644605
# 2              1       1             Jigani,Bangalore  12.778033  77.632191
# 3              1       1  Sector-1 Vaishali,Ghaziabad  28.642300  77.344500
# 4              0       1             New Town,Kolkata  22.592200  88.484911
#
#    TARGET(PRICE_IN_LACS)
# 0                   55.0
# 1                   51.0
# ...

# %%
df['BHK_OR_RK'].unique()
a={'BHK':0,'RK':1}
df.replace(a,inplace=True)

# %%
df.head()
# Out:
#    POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO.  BHK_OR_RK    SQUARE_FT  \
# 0          0                   0     0        2          0  1300.236407
# 1          1                   0     0        2          0  1275.000000
# 2          0                   0     0        2          0   933.159722
# 3          0                   0     1        2          0   929.921143
# 4          1                   1     0        2          0   999.009247
#
#    READY_TO_MOVE  RESALE                      ADDRESS  LONGITUDE   LATITUDE  \
# 0              1       1        Ksfc Layout,Bangalore  12.969910  77.597960
# 1              1       1    Vishweshwara Nagar,Mysore  12.274538  76.644605
# 2              1       1             Jigani,Bangalore  12.778033  77.632191
# 3              1       1  Sector-1 Vaishali,Ghaziabad  28.642300  77.344500
# 4              0       1             New Town,Kolkata  22.592200  88.484911
#
#    TARGET(PRICE_IN_LACS)
# 0                   55.0
# ...

# %% [markdown]
# now we deploy ML Alogritm model

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
df.drop('ADDRESS',axis=1,inplace=True)

# %%
df.head()
# Out:
#    POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO.  BHK_OR_RK    SQUARE_FT  \
# 0          0                   0     0        2          0  1300.236407
# 1          1                   0     0        2          0  1275.000000
# 2          0                   0     0        2          0   933.159722
# 3          0                   0     1        2          0   929.921143
# 4          1                   1     0        2          0   999.009247
#
#    READY_TO_MOVE  RESALE  LONGITUDE   LATITUDE  TARGET(PRICE_IN_LACS)
# 0              1       1  12.969910  77.597960                   55.0
# 1              1       1  12.274538  76.644605                   51.0
# 2              1       1  12.778033  77.632191                   43.0
# 3              1       1  28.642300  77.344500                   62.5
# 4              0       1  22.592200  88.484911                   60.5

# %%
df['TARGET_PRICE_IN_LACS']=df['TARGET(PRICE_IN_LACS)'].astype(int)

# %%
df['TARGET_PRICE_IN_LACS'].astype(int)
# Out:
# 0        55
# 1        51
# 2        43
# 3        62
# 4        60
#          ..
# 29446    45
# 29447    16
# 29448    27
# 29449    67
# 29450    27
# Name: TARGET_PRICE_IN_LACS, Length: 29050, dtype: int64

# %%
df.drop('TARGET(PRICE_IN_LACS)',axis=1,inplace=True)

# %%
df.head()
# Out:
#    POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO.  BHK_OR_RK    SQUARE_FT  \
# 0          0                   0     0        2          0  1300.236407
# 1          1                   0     0        2          0  1275.000000
# 2          0                   0     0        2          0   933.159722
# 3          0                   0     1        2          0   929.921143
# 4          1                   1     0        2          0   999.009247
#
#    READY_TO_MOVE  RESALE  LONGITUDE   LATITUDE  TARGET_PRICE_IN_LACS
# 0              1       1  12.969910  77.597960                    55
# 1              1       1  12.274538  76.644605                    51
# 2              1       1  12.778033  77.632191                    43
# 3              1       1  28.642300  77.344500                    62
# 4              0       1  22.592200  88.484911                    60

# %%
X=df.drop(labels=["TARGET_PRICE_IN_LACS"],axis=1)
y=df.TARGET_PRICE_IN_LACS

# %%
#ML models
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size = 0.20, random_state = 0)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

x_train_scaled = scaler.fit_transform(X_train)
x_test_scaled = scaler.transform(X_test)

# %%
from sklearn.metrics import r2_score
XB=XGBRegressor()
XB.fit(X_train, y_train)
y_predict= XB.predict(X_test)
XB_score= r2_score(y_predict,y_test)
print(f"{round(XB_score*100,2)}% Accurate")
print(XB_score)
# Out:
# 92.29% Accurate
# 0.9228973327364088

# %%
from sklearn.linear_model import Lasso
RG=Lasso()
RG.fit(X_train, y_train)
y_predict= XB.predict(X_test)
RG_score= r2_score(y_predict,y_test)
print(f"{round(RG_score*100,2)}% Accurate")
print(RG_score)
# Out:
# 92.29% Accurate
# 0.9228973327364088

# %%
DT = DecisionTreeRegressor()
DT.fit(X_train, y_train)

y_predict = DT.predict(X_test)

#  prediction Summary by species
#print(r2_score(y_test, y_predict))

# Accuracy score
DT_SC = r2_score(y_predict,y_test)
print(f"{round(DT_SC*100,2)}% Accurate")
# Out:
# 92.55% Accurate

# %%
warnings.filterwarnings("ignore")
RF = RandomForestRegressor(n_estimators=14)
RF.fit(X_train, y_train)

y_predict = RF.predict(X_test)

# Accuracy score
RF_SC = r2_score(y_predict,y_test)
print(f"{round(RF_SC*100,2)}% Accurate")
# Out:
# 95.16% Accurate

# %%
#RF_SC
# Out:
# 0.9515782742134571

# %%
from sklearn import svm
from sklearn.svm import SVC
from sklearn.metrics import mean_squared_error

model_SVR = svm.SVR()
model_SVR.fit(X_train,y_train)
y_predict = model_SVR.predict(X_test)
svm=mean_squared_error(y_test, y_predict)
print(f"{round(svm*100,2)}% Accurate")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-336ded980fe9> in <cell line: 7>()
#       5 model_SVR = svm.SVR()
#       6 model_SVR.fit(X_train,y_train)
# ----> 7 y_predict = model_SVR.predict(X_test)
#       8 svm=mean_squared_error(y_test, y_predict)
#       9 print(f"{round(svm*100,2)}% Accurate")
#
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py in predict(self, X)
#     433         X = self._validate_for_predict(X)
#     434         predict = self._sparse_predict if self._sparse else self._dense_predict
# --> 435         return predict(X)
#     436
#     437     def _dense_predict(self, X):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py in _dense_predict(self, X)
#     452         svm_type = LIBSVM_IMPL.index(self._impl)
#     453
# --> 454         return libsvm.predict(
#     455             X,
# ...

# %%
from sklearn.linear_model import LinearRegression

model_LR = LinearRegression()
model_LR.fit(X_train, y_train)
y_predict= model_LR.predict(X_test)

print("Accuracy= ",mean_squared_error(y_test, y_predict))
# Out:
# Accuracy=  312771.4272389186

# %%
pip install catboost
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.3 MB/s eta 0:00:00
# ...

# %%
from catboost import CatBoostRegressor
from sklearn.metrics import r2_score
cb_model = CatBoostRegressor()
cb_model.fit(X_train, y_train)
preds = cb_model.predict(X_test)
cb_r2_score=r2_score(y_test, preds)
#print("accuracy= ",cb_r2_score)
CAT=print(f"{round(cb_r2_score*100,2)}% Accurate")
# Out:
# Learning rate set to 0.067305
# 0:	learn: 636.5375472	total: 34.3ms	remaining: 34.2s
# 1:	learn: 606.4864254	total: 63.5ms	remaining: 31.7s
# 2:	learn: 580.2822688	total: 80.9ms	remaining: 26.9s
# 3:	learn: 554.1265628	total: 95.6ms	remaining: 23.8s
# 4:	learn: 531.2806770	total: 121ms	remaining: 24.1s
# 5:	learn: 508.0245826	total: 129ms	remaining: 21.4s
# 6:	learn: 488.1565605	total: 139ms	remaining: 19.8s
# 7:	learn: 469.8309866	total: 149ms	remaining: 18.5s
# 8:	learn: 453.7666359	total: 160ms	remaining: 17.6s
# 9:	learn: 435.0691885	total: 175ms	remaining: 17.3s
# 10:	learn: 419.6634280	total: 184ms	remaining: 16.6s
# 11:	learn: 403.6986455	total: 194ms	remaining: 15.9s
# 12:	learn: 387.9632871	total: 203ms	remaining: 15.4s
# 13:	learn: 373.4620329	total: 210ms	remaining: 14.8s
# 14:	learn: 360.0415923	total: 219ms	remaining: 14.4s
# 15:	learn: 348.5960552	total: 230ms	remaining: 14.2s
# 16:	learn: 337.1958943	total: 259ms	remaining: 15s
# ...

# %%
print(f"{round(cb_r2_score*100,2)}% Accurate")
# Out:
# 92.24% Accurate

# %% [markdown]
# Deep Learning Model

# %%
pip install keras

# %%
from sklearn.model_selection import train_test_split

# %%
pip install keras_tuner
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.5/129.5 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 24.9 MB/s eta 0:00:00
# ...

# %%
import keras_tuner as kt
# Out:
# Using TensorFlow backend

# %%
import tensorflow

from tensorflow.keras import Sequential
from tensorflow import keras
from tensorflow.keras.layers import Dense

# %%
model= Sequential()

# %%
import keras_tuner as kt

# %%
def build_model(hp):

  model = Sequential()

  counter = 0

  for i in range(hp.Int('num_layers',min_value = 1,max_value = 8)):
    if counter == 0:
      model.add(Dense(hp.Int('units',min_value = 8, max_value = 228,step = 8),
                      activation = hp.Choice('activation',values = ['relu','tanh','activation']),
                      input_dim = 10
                      )
      )

    else:
      model.add(Dense(hp.Int('units',min_value = 8, max_value = 228,step = 8),
                      activation = hp.Choice('activation',values = ['relu','tanh','activation'])
                      )
      )

    counter = counter+1

  model.add(Dense(1,activation = 'linear'))

  model.compile(optimizer = hp.Choice('optimizer',values = ['adam','rmsprop','adadelta','sgd']),
                  loss = hp.Choice('loss',values = ['mean_squared_error','mean_absolute_error']),
                metrics = ['mse'])

  return model

# %%
tuner = kt.RandomSearch(build_model,
                       objective ='mse',
                       max_trials = 5,
                       directory = 'house_dir',
                       project_name = 'House Price Prediction')

# %%
tuner.search(X_train,y_train,epochs = 5,validation_data = (X_test,y_test))
# Out:
# Trial 5 Complete [00h 00m 00s]
#
# Best mse So Far: 461099.96875
# Total elapsed time: 00h 01m 09s

# %%
model = tuner.get_best_models(num_models=1)[0]

# %%
from keras.callbacks import EarlyStopping

# %%
callback = EarlyStopping(monitor = 'val_loss',
                         min_delta = 0.001,
                         patience = 8,
                         verbose = 1,
                         mode = 'auto',
                         baseline = None,
                         restore_best_weights = True,
                         )

# %%
history = model.fit(X_train,y_train,batch_size = 44,epochs = 100,initial_epoch = 6,validation_data = (X_test,y_test),callbacks = [callback])
# Out:
# Epoch 7/100
# 529/529 [==============================] - 4s 6ms/step - loss: 460763.2500 - mse: 460763.2500 - val_loss: 354622.2188 - val_mse: 354622.2188
# Epoch 8/100
# 529/529 [==============================] - 3s 6ms/step - loss: 460492.6562 - mse: 460492.6562 - val_loss: 354369.8750 - val_mse: 354369.8750
# Epoch 9/100
# 529/529 [==============================] - 3s 6ms/step - loss: 460227.0625 - mse: 460227.0625 - val_loss: 354120.6875 - val_mse: 354120.6875
# Epoch 10/100
# 529/529 [==============================] - 4s 8ms/step - loss: 459993.5000 - mse: 459993.5000 - val_loss: 353915.7812 - val_mse: 353915.7812
# Epoch 11/100
# 529/529 [==============================] - 3s 6ms/step - loss: 459811.0625 - mse: 459811.0625 - val_loss: 353765.5938 - val_mse: 353765.5938
# Epoch 12/100
# 529/529 [==============================] - 3s 6ms/step - loss: 459653.1875 - mse: 459653.1875 - val_loss: 353608.8750 - val_mse: 353608.8750
# Epoch 13/100
# ...

# %%
y_pred = model.predict(X_test)
# Out:
# 182/182 [==============================] - 0s 2ms/step

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 224)               2464
#
#  dense_1 (Dense)             (None, 224)               50400
#
#  dense_2 (Dense)             (None, 224)               50400
#
#  dense_3 (Dense)             (None, 224)               50400
#
#  dense_4 (Dense)             (None, 1)                 225
#
# ...
# Total params: 153889 (601.13 KB)
# Trainable params: 153889 (601.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
y_pred = model.predict(X_test)
# Out:
# 182/182 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import mean_absolute_error,r2_score

ann,ann=mean_absolute_error(y_test,y_pred), r2_score(y_test,y_pred)
print(f"{round(ann*100,2)}% Accurate")
# Out:
# -3.69% Accurate

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
Model_score = [CAT,RF_SC,XB_score,RG_score,DT_SC,ann]
Models = pd.DataFrame({
    'Model_Name': ["Lasso","Random Forest","Decision Tree","XGBRegressor",
                   "CatBoost","ANN",],
    'Score':Model_score})
Models.sort_values(by='Score', ascending=False)
# Out:
#       Model_Name     Score
# 1  Random Forest  0.951578
# 4       CatBoost  0.925480
# 2  Decision Tree  0.922897
# 3   XGBRegressor  0.922897
# 5            ANN -0.036889
# 0          Lasso       NaN
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5['Score'].plot(kind='hist', bins=20, title='Score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('Model_Name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# ...
